# %% [markdown]
# # Step 1. Import libraries and load data

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load the data
jeju_reg_17_df = pd.read_csv('../data/jeju_card_region_2017_english.csv')
jeju_reg_18_df = pd.read_csv('../data/jeju_card_region_2018_english.csv')
jeju_pop_df = pd.read_csv('../data/jeju_population_english.csv')

# %% [markdown]
# # Step 2. Explore data

# %%
print(jeju_reg_17_df.shape) 
print(jeju_reg_18_df.shape)
print(jeju_pop_df.shape)
# Out:
# (26968, 7)
# (27183, 7)
# (527026, 6)

# %%
jeju_reg_17_df.head()
# Out:
#    Year_Month City/County_Life_Name Eup/myeon/dong_name  \
# 0  2017-01-01         Seogwipo City          Namwon-eup
# 1  2017-01-01         Seogwipo City        Cheonji-dong
# 2  2017-01-01         Seogwipo City        Daejeong-eup
# 3  2017-01-01         Seogwipo City        Daejeong-eup
# 4  2017-01-01         Seogwipo City        Daejeong-eup
#
#                                        Industry_name  gender  Number_of_users  \
# 0                        Health supplement retailing    male               11
# 1                        Health supplement retailing  female               61
# 2  General retail business focusing on other food...    male              555
# 3                                 Other bar business    male              324
# 4                  Other foreign restaurant business    male               40
#
#    Usage_amount
# 0        137500
# 1      12334400
# 2      17301300
# 3      71843080
# 4        971000

# %%
jeju_reg_18_df.head()
# Out:
#    Year_Month City/County_Life_Name Eup/myeon/dong_name  \
# 0  2018-01-01             Jeju City             Aradong
# 1  2018-01-01             Jeju City        Samdo 1-dong
# 2  2018-01-01             Jeju City        Samdo 2-dong
# 3  2018-01-01             Jeju City        Samdo 1-dong
# 4  2018-01-01             Jeju City        Samdo 1-dong
#
#                                        Industry_name  gender  Number_of_users  \
# 0             Vehicle gas station operation business    male             3954
# 1             Vehicle gas station operation business    male              490
# 2                                        meat retail  female               89
# 3  Sports and recreational equipment rental business    male              106
# 4                                     seafood retail    male               37
#
#    Usage_amount
# 0     205339045
# 1      29469792
# 2       2386740
# 3      12517300
# 4       2621000

# %%
jeju_pop_df.head()
# Out:
#    year_month_day City/County_Life_Name Eup/myeon/dong_name  gender age_range  \
# 0        20170101             Jeju City          Hallim-eup   other       40s
# 1        20170101             Jeju City           Aewol-eup  female       20s
# 2        20170101             Jeju City           Gujwa-eup   other       70s
# 3        20170101             Jeju City         Jocheon-eup   other       40s
# 4        20170101             Jeju City     Hangyeong-myeon   other       70s
#
#    Visiting_population
# 0                19424
# 1                27747
# 2                 3459
# 3                36695
# 4                 1174

# %%
jeju_reg_17_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26968 entries, 0 to 26967
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year_Month             26968 non-null  object
#  1   City/County_Life_Name  26968 non-null  object
#  2   Eup/myeon/dong_name    26968 non-null  object
#  3   Industry_name          26968 non-null  object
#  4   gender                 26968 non-null  object
#  5   Number_of_users        26968 non-null  int64
#  6   Usage_amount           26968 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ MB

# %%
jeju_reg_18_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27183 entries, 0 to 27182
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year_Month             27183 non-null  object
#  1   City/County_Life_Name  27183 non-null  object
#  2   Eup/myeon/dong_name    27183 non-null  object
#  3   Industry_name          27183 non-null  object
#  4   gender                 27183 non-null  object
#  5   Number_of_users        27183 non-null  int64
#  6   Usage_amount           27183 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.5+ MB

# %%
jeju_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527026 entries, 0 to 527025
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year_month_day         527026 non-null  int64
#  1   City/County_Life_Name  527026 non-null  object
#  2   Eup/myeon/dong_name    527026 non-null  object
#  3   gender                 527026 non-null  object
#  4   age_range              527026 non-null  object
#  5   Visiting_population    527026 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 24.1+ MB

# %%
pd.options.display.float_format = '{:.3f}'.format

jeju_reg_17_df.describe(include='all')
# Out:
#         Year_Month City/County_Life_Name Eup/myeon/dong_name  \
# count        26968                 26968               26968
# unique          12                     2                  43
# top     2017-11-01             Jeju City       Nohyeong-dong
# freq          2265                 16076                 795
# mean           NaN                   NaN                 NaN
# std            NaN                   NaN                 NaN
# min            NaN                   NaN                 NaN
# 25%            NaN                   NaN                 NaN
# 50%            NaN                   NaN                 NaN
# 75%            NaN                   NaN                 NaN
# max            NaN                   NaN                 NaN
#
#                      Industry_name gender  Number_of_users   Usage_amount
# count                        26968  26968        26968.000      26968.000
# unique                          41      2              NaN            NaN
# top     Korean restaurant business   male              NaN            NaN
# freq                          1032  13518              NaN            NaN
# mean                           NaN    NaN         1703.495   63231393.341
# std                            NaN    NaN         4313.161  198798394.063
# min                            NaN    NaN            1.000         10.000
# 25%                            NaN    NaN           43.000    2635000.000
# 50%                            NaN    NaN          281.000   12125170.000
# 75%                            NaN    NaN         1333.250   49059281.000
# max                            NaN    NaN        62761.000 5092989749.000

# %%
jeju_reg_18_df.describe(include='all')
# Out:
#         Year_Month City/County_Life_Name Eup/myeon/dong_name  \
# count        27183                 27183               27183
# unique          12                     2                  43
# top     2018-09-01             Jeju City       Nohyeong-dong
# freq          2285                 16228                 812
# mean           NaN                   NaN                 NaN
# std            NaN                   NaN                 NaN
# min            NaN                   NaN                 NaN
# 25%            NaN                   NaN                 NaN
# 50%            NaN                   NaN                 NaN
# 75%            NaN                   NaN                 NaN
# max            NaN                   NaN                 NaN
#
#                      Industry_name gender  Number_of_users   Usage_amount
# count                        27183  27183        27183.000      27183.000
# unique                          41      2              NaN            NaN
# top     Korean restaurant business   male              NaN            NaN
# freq                          1032  13645              NaN            NaN
# mean                           NaN    NaN         1726.604   62044256.570
# std                            NaN    NaN         4399.634  190042848.439
# min                            NaN    NaN            1.000         10.000
# 25%                            NaN    NaN           45.000    2706600.000
# 50%                            NaN    NaN          288.000   12311900.000
# 75%                            NaN    NaN         1339.000   49426169.000
# max                            NaN    NaN        63621.000 4836250309.000

# %%
jeju_pop_df.describe(include='all')
# Out:
#         year_month_day City/County_Life_Name Eup/myeon/dong_name  gender  \
# count       527026.000                527026              527026  527026
# unique             NaN                     2                  43       2
# top                NaN             Jeju City        Samdo 1-dong  female
# freq               NaN                318669               12264  263533
# mean      20175307.456                   NaN                 NaN     NaN
# std           4999.286                   NaN                 NaN     NaN
# min       20170101.000                   NaN                 NaN     NaN
# 25%       20170620.000                   NaN                 NaN     NaN
# 50%       20171207.000                   NaN                 NaN     NaN
# 75%       20180526.000                   NaN                 NaN     NaN
# max       20181231.000                   NaN                 NaN     NaN
#
#        age_range  Visiting_population
# count     527026           527026.000
# unique         9                  NaN
# top          60s                  NaN
# freq       58592                  NaN
# mean         NaN             9931.281
# std          NaN             9974.524
# min          NaN                0.000
# 25%          NaN             3292.000
# 50%          NaN             6811.000
# 75%          NaN            12783.000
# max          NaN            98444.000

# %% [markdown]
# # Step 3. Data Preprocessing and Comparison: 2017 vs. 2018

# %%
def print_unique_values(df):
    object_columns = df.columns[df.dtypes == 'object']
    for col in object_columns:
        print(f"Number of unique values in the '{col}' column: {df[col].nunique()}")
        print(sorted(df[col].unique()), '\n')

print_unique_values(jeju_reg_17_df)
# Out:
# Number of unique values in the 'Year_Month' column: 12
# ['2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01']
#
# Number of unique values in the 'City/County_Life_Name' column: 2
# ['Jeju City', 'Seogwipo City']
#
# Number of unique values in the 'Eup/myeon/dong_name' column: 43
# ['Aewol-eup', 'Andeok-myeon', 'Aradong', 'Bonggae-dong', 'Cheonji-dong', 'Daecheon-dong', 'Daejeong-eup', 'Daeryun-dong', 'Dodu-dong', 'Donghong-dong', 'Geonip-dong', 'Gujwa-eup', 'Hallim-eup', 'Hangyeong-myeon', 'Hwabuk-dong', 'Hyodon-dong', 'Ido 1-dong', 'Ido 2-dong', 'Ildo 1-dong', 'Ildo 2-dong', 'Jeongbang-dong', 'Jocheon-eup', 'Jungang-dong', 'Jungmun-dong', 'Lee Ho-dong', "Let's do it", 'Namwon-eup', 'Nohyeong-dong', 'Oedo-dong', 'Ora-dong', 'Pyoseon-myeon', 'Samdo 1-dong', 'Samdo 2-dong', 'Samyang-dong', 'Seohong-dong', 'Seongsan-eup', 'Songsan-dong', 'Udo-myeon', 'Yeongcheon-dong', 'Yerae-dong', 'Yongdam 1-dong', 'Yongdam 2-dong', 'peristalsis']
#
# Number of unique values in the 'Industry_name' column: 41
# ['Bath business', 'Bread and confectionery retail', 'Chinese restaurant industry', 'Cosmetics and fragrance retail', 'Exhibition and event agency business', 'Fruit and Vegetable Retail', 'Gas refilling business for vehicles', 'General entertainment bar business', 'General retail business focusing on other food products', 'Golf course operation business', 'Health supplement retailing', 'Inner port passenger transportation industry', 'Japanese restaurant industry', 'Korean restaurant business', 'Non-alcoholic beverage store', 'Other bar business', 'Other foreign restaurant business', 'Other gambling and betting businesses', 'Other general retail stores', 'Other large general retail stores', 'Other sports facility operation business', 'Other unclassified entertainment-related service industries', 'Other water entertainment service industry', 'Pizza, hamburger, sandwich and similar restaurant business', 'Recreational condo operation business', 'Sports and recreational equipment rental business', 'Tourism Folk Crafts and Gifts Retail', 'Vehicle gas station operation business', 'Western-style restaurant business', 'bus transportation', 'car rental business', 'chain convenience store', 'duty free shop', 'hotel industry', 'inn business', 'massage business', 'meat retail', 'scheduled air transport', 'seafood retail', 'supermarket', 'travel business']
#
# Number of unique values in the 'gender' column: 2
# ['female', 'male']

# %%
print_unique_values(jeju_reg_18_df)
# Out:
# Number of unique values in the 'Year_Month' column: 12
# ['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01']
#
# Number of unique values in the 'City/County_Life_Name' column: 2
# ['Jeju City', 'Seogwipo City']
#
# Number of unique values in the 'Eup/myeon/dong_name' column: 43
# ['Aewol-eup', 'Andeok-myeon', 'Aradong', 'Bonggae-dong', 'Cheonji-dong', 'Daecheon-dong', 'Daejeong-eup', 'Daeryun-dong', 'Dodu-dong', 'Donghong-dong', 'Geonip-dong', 'Gujwa-eup', 'Hallim-eup', 'Hangyeong-myeon', 'Hwabuk-dong', 'Hyodon-dong', 'Ido 1-dong', 'Ido 2-dong', 'Ildo 1-dong', 'Ildo 2-dong', 'Jeongbang-dong', 'Jocheon-eup', 'Jungang-dong', 'Jungmun-dong', 'Lee Ho-dong', "Let's do it", 'Namwon-eup', 'Nohyeong-dong', 'Oedo-dong', 'Ora-dong', 'Pyoseon-myeon', 'Samdo 1-dong', 'Samdo 2-dong', 'Samyang-dong', 'Seohong-dong', 'Seongsan-eup', 'Songsan-dong', 'Udo-myeon', 'Yeongcheon-dong', 'Yerae-dong', 'Yongdam 1-dong', 'Yongdam 2-dong', 'peristalsis']
#
# Number of unique values in the 'Industry_name' column: 41
# ['Bath business', 'Bread and confectionery retail', 'Chinese restaurant industry', 'Cosmetics and fragrance retail', 'Exhibition and event agency business', 'Fruit and Vegetable Retail', 'Gas refilling business for vehicles', 'General entertainment bar business', 'General retail business focusing on other food products', 'Golf course operation business', 'Health supplement retailing', 'Inner port passenger transportation industry', 'Japanese restaurant industry', 'Korean restaurant business', 'Non-alcoholic beverage store', 'Other bar business', 'Other foreign restaurant business', 'Other general retail stores', 'Other large general retail stores', 'Other sports facility operation business', 'Other unclassified entertainment-related service industries', 'Other water entertainment service industry', 'Pizza, hamburger, sandwich and similar restaurant business', 'Recreational condo operation business', 'Sports and recreational equipment rental business', 'Tourism Folk Crafts and Gifts Retail', 'Vehicle gas station operation business', 'Western-style restaurant business', 'bus transportation', 'car rental business', 'chain convenience store', 'duty free shop', 'hotel industry', 'inn business', 'massage business', 'meat retail', 'scheduled air transport', 'seafood retail', 'supermarket', 'taxi transportation industry', 'travel business']
#
# Number of unique values in the 'gender' column: 2
# ['female', 'male']
